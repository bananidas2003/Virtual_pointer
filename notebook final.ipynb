# %%
# !pip install mediapipe==0.10.21
# Out:
# Collecting mediapipe==0.10.21
#   Using cached mediapipe-0.10.21-cp312-cp312-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: absl-py in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from mediapipe==0.10.21) (2.3.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from mediapipe==0.10.21) (25.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from mediapipe==0.10.21) (25.9.23)
# Requirement already satisfied: jax in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from mediapipe==0.10.21) (0.7.1)
# Requirement already satisfied: jaxlib in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from mediapipe==0.10.21) (0.7.1)
# Requirement already satisfied: matplotlib in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from mediapipe==0.10.21) (3.10.0)
# Requirement already satisfied: numpy<2 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from mediapipe==0.10.21) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from mediapipe==0.10.21) (4.11.0.86)
# Collecting protobuf<5,>=4.25.3 (from mediapipe==0.10.21)
#   Using cached protobuf-4.25.9-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from mediapipe==0.10.21) (0.5.3)
# Requirement already satisfied: sentencepiece in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from mediapipe==0.10.21) (0.2.1)
# Requirement already satisfied: CFFI>=1.0 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from sounddevice>=0.4.4->mediapipe==0.10.21) (2.0.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from jax->mediapipe==0.10.21) (0.5.4)
# Requirement already satisfied: opt_einsum in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from jax->mediapipe==0.10.21) (3.4.0)
# Requirement already satisfied: scipy>=1.12 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from jax->mediapipe==0.10.21) (1.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from matplotlib->mediapipe==0.10.21) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from matplotlib->mediapipe==0.10.21) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from matplotlib->mediapipe==0.10.21) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from matplotlib->mediapipe==0.10.21) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from matplotlib->mediapipe==0.10.21) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from matplotlib->mediapipe==0.10.21) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from matplotlib->mediapipe==0.10.21) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from matplotlib->mediapipe==0.10.21) (2.9.0.post0)
# Requirement already satisfied: pycparser in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe==0.10.21) (2.23)
# Requirement already satisfied: six>=1.5 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe==0.10.21) (1.17.0)
# Using cached mediapipe-0.10.21-cp312-cp312-win_amd64.whl (51.0 MB)
# Using cached protobuf-4.25.9-cp310-abi3-win_amd64.whl (413 kB)
# Installing collected packages: protobuf, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# Successfully installed mediapipe-0.10.21 protobuf-4.25.9
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install opencv-python pyautogui pillow numpy
# Out:
# Requirement already satisfied: opencv-python in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (4.11.0.86)
# Requirement already satisfied: pyautogui in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (0.9.54)
# Requirement already satisfied: pillow in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (11.1.0)
# Requirement already satisfied: numpy in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (1.26.4)
# Requirement already satisfied: pymsgbox in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from pyautogui) (2.0.1)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from pyautogui) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from pyautogui) (1.0.1)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: pyperclip in c:\users\91983\onedrive\documents\desktop\machine_learning\myenv\lib\site-packages (from mouseinfo->pyautogui) (1.11.0)
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python virtual_mouse.py
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1778405608.438056   54740 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778405608.474928   54816 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778405616.023343   36132 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
